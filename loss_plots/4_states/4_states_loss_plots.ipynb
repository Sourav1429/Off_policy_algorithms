# %%
import pickle
from matplotlib import pyplot as plt
import numpy as np
nS = 10
with open("Off_policy_1"+str(nS)+"_states_details",'rb') as f:
    dictionary = pickle.load(f)

# %%
plt.plot(dictionary[0]['loss'])
plt.xlabel('Instance');
plt.ylabel('Loss')
# Out:
# Text(0, 0.5, 'Loss')

# %%
plt.plot(dictionary[1]['loss'])
plt.xlabel('Instance');
plt.ylabel('Loss')
# Out:
# Text(0, 0.5, 'Loss')

# %%
plt.plot(dictionary[2]['loss'])
plt.xlabel('Instance');
plt.ylabel('Loss')
# Out:
# Text(0, 0.5, 'Loss')

# %%
plt.plot(dictionary[3]['loss'])
plt.xlabel('Instance');
plt.ylabel('Loss')
# Out:
# Text(0, 0.5, 'Loss')

# %%
t=len(dictionary[0]['loss'])
plt.plot(dictionary[0]['loss']/np.arange(1,t+1))
plt.ylabel('Progressive loss')
plt.xlabel('Instances')
# Out:
# Text(0.5, 0, 'Instances')

# %%
t=len(dictionary[0]['loss'])
plt.plot(dictionary[1]['loss']/np.arange(1,t+1))
plt.ylabel('Progressive loss')
plt.xlabel('Instances')
# Out:
# Text(0.5, 0, 'Instances')

# %%
t=len(dictionary[0]['loss'])
plt.plot(dictionary[2]['loss']/np.arange(1,t+1))
plt.ylabel('Progressive loss')
plt.xlabel('Instances')
# Out:
# Text(0.5, 0, 'Instances')

# %%
t=len(dictionary[0]['loss'])
plt.plot(dictionary[3]['loss']/np.arange(1,t+1))
plt.ylabel('Progressive loss')
plt.xlabel('Instances')
# Out:
# Text(0.5, 0, 'Instances')
