# %%
import pickle
from matplotlib import pyplot as plt
import numpy as np
nS = 10
path = "/home/user/off_policy_algorithms/loss_plots_upto_2000_time_steps/constant_step_size/"
with open("Off_policy_1_"+str(nS)+"_states_details",'rb') as f:
    dictionary = pickle.load(f)

# %%
plt.plot(dictionary[0]['loss'])
plt.xlabel('Instance');
plt.ylabel('Loss')
plt.savefig(path+"1st_policy");

# %%
plt.plot(dictionary[1]['loss'])
plt.xlabel('Instance');
plt.ylabel('Loss')
plt.savefig(path+"2nd_policy");

# %%
plt.plot(dictionary[2]['loss'])
plt.xlabel('Instance');
plt.ylabel('Loss')
plt.savefig(path+"3rd_policy");

# %%
plt.plot(dictionary[3]['loss'])
plt.xlabel('Instance');
plt.ylabel('Loss')
plt.savefig(path+"4th_policy");

# %%
plt.plot(dictionary[4]['loss'])
plt.xlabel('Instance');
plt.ylabel('Loss')
plt.savefig(path+"5th_policy");

# %%
plt.plot(dictionary[5]['loss'])
plt.xlabel('Instance');
plt.ylabel('Loss')
plt.savefig(path+"6th_policy");

# %%
plt.plot(dictionary[6]['loss'])
plt.xlabel('Instance');
plt.ylabel('Loss')
plt.savefig(path+"7th_policy");

# %%
plt.plot(dictionary[7]['loss'])
plt.xlabel('Instance');
plt.ylabel('Loss')
plt.savefig(path+"8th_policy");

# %%
plt.plot(dictionary[8]['loss'])
plt.xlabel('Instance');
plt.ylabel('Loss')
plt.savefig(path+"9th_policy");

# %%
t=len(dictionary[0]['loss'])
plt.plot(dictionary[0]['loss']/np.arange(1,t+1))
plt.ylabel('Progressive loss')
plt.xlabel('Instances')
plt.savefig(path+"progressive_loss_1st_policy");

# %%
t=len(dictionary[0]['loss'])
plt.plot(dictionary[1]['loss']/np.arange(1,t+1))
plt.ylabel('Progressive loss')
plt.xlabel('Instances')
plt.savefig(path+"progressive_loss_2nd_policy");

# %%
t=len(dictionary[0]['loss'])
plt.plot(dictionary[2]['loss']/np.arange(1,t+1))
plt.ylabel('Progressive loss')
plt.xlabel('Instances')
plt.savefig(path+"progressive_loss_3rd_policy");

# %%
t=len(dictionary[0]['loss'])
plt.plot(dictionary[3]['loss']/np.arange(1,t+1))
plt.ylabel('Progressive loss')
plt.xlabel('Instances')
plt.savefig(path+"progressive_loss_4th_policy");

# %%
t=len(dictionary[0]['loss'])
plt.plot(dictionary[4]['loss']/np.arange(1,t+1))
plt.ylabel('Progressive loss')
plt.xlabel('Instances')
plt.savefig(path+"progressive_loss_5th_policy");

# %%
t=len(dictionary[0]['loss'])
plt.plot(dictionary[5]['loss']/np.arange(1,t+1))
plt.ylabel('Progressive loss')
plt.xlabel('Instances')
plt.savefig(path+"progressive_loss_6th_policy");

# %%
t=len(dictionary[0]['loss'])
plt.plot(dictionary[6]['loss']/np.arange(1,t+1))
plt.ylabel('Progressive loss')
plt.xlabel('Instances')
plt.savefig(path+"progressive_loss_7th_policy");

# %%
t=len(dictionary[0]['loss'])
plt.plot(dictionary[7]['loss']/np.arange(1,t+1))
plt.ylabel('Progressive loss')
plt.xlabel('Instances')
plt.savefig(path+"progressive_loss_8th_policy");

# %%
t=len(dictionary[0]['loss'])
plt.plot(dictionary[8]['loss']/np.arange(1,t+1))
plt.ylabel('Progressive loss')
plt.xlabel('Instances')
plt.savefig(path+"progressive_loss_9th_policy");
